# %% [markdown]
# ## Belajar Dasar Python
#
# #### Oleh: Reza Rizky Pratama & Bakhtiar Amaludin
# #### MoF-DAC

# %% [markdown]
# ## Python Calculator
#
# ![image.png](attachment:image.png)

# %%
# Python as your Calculator 
23 + 4 + 2020 * 1
# Out:
# 2047

# %%
# Python as your Calculator II
5 ** 3
# Out:
# 125

# %% [markdown]
# ## Materi
#
# - Variable dan Tipe Data
# - Arithmatic Operator
# - Logical Operator
# - Data Structure
# - Flow Control
# - Function
# - Libraries

# %% [markdown]
# ## Variable dan Tipe Data
#
# - integer
# - float
# - string
# - boolean

# %%
# inisiasi variable

# contoh integer

# contoh string

# contoh boolean

# casting/type conversion

# %% [markdown]
# ## Arithmatic Operator
#
# ![image.png](attachment:image.png)

# %%
# Penjumlahan (+)

# Pengurangan (-)

# Pembagian (/ atau //)

# Perkalian (*)

# Eksponensial (**)

# Modulo (%)

# %% [markdown]
# ## Logical Operator
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Data Structure
#
# - List
# - Tuple
# - Dictionary
# - Set

# %% [markdown]
# ## Flow Control
#
# - Conditional Statement (If...elif....else...)
# - For Loop
# - While Loop

# %%
if condition:
    # baris dieksekusi jika condtion == True    
elif condition:
    
else:
